# %% [markdown]
# # Manipulacion de series y dataframes (Ejemplo en vivo)

# %% [markdown]
# <ol>
#     <li> <strong>Python</strong>: No tiene una estructura "Serie", pero puedes usar listas o diccionarios como alternativas unidimensionales.
#     <li><strong>Pandas</strong>: Usa Series, que son estructuras unidimensionales con índices personalizados, similares a los arreglos de NumPy pero más flexibles.
#     <li><strong>NumPy</strong>: Trabaja con arreglos (arrays), que son unidimensionales pero no tienen índices personalizados como las Series de Pandas.
#
#
# <ol>

# %%
# Series de ejemplo
import pandas as pd

Numeros = range(50,70,2)
print(Numeros)

print("-------Pandas puede convertir un rango en un df----------")


print("-------Pandas trabaja con series----------")

Numeros_Serie = pd.Series(Numeros)
print(Numeros_Serie)
# Out:
# range(50, 70, 2)
# -------Pandas puede convertir un rango en un df----------
# -------Pandas trabaja con series----------
# 0    50
# 1    52
# 2    54
# 3    56
# 4    58
# 5    60
# 6    62
# 7    64
# 8    66
# 9    68
# dtype: int64

# %%
print("-------Columna index generada por defecto por python----------")

Numero_Series_2a = pd.Series(Numeros)
print(Numero_Series_2a)

print("-------Columna index generada por mi----------")

Numeros_texto= ['primero','segundo','tercero','cuarto','quinto','sexto','septimo','octavo','noveno','decimo']
Numero_Series_2 = pd.Series(Numeros,index=Numeros_texto)
print(Numero_Series_2)
# Out:
# -------Columna index generada por defecto por python----------
# 0    50
# 1    52
# 2    54
# 3    56
# 4    58
# 5    60
# 6    62
# 7    64
# 8    66
# 9    68
# dtype: int64
# -------Columna index generada por mi----------
# primero    50
# segundo    52
# tercero    54
# cuarto     56
# quinto     58
# sexto      60
# septimo    62
# octavo     64
# noveno     66
# decimo     68
# dtype: int64

# %%
Numeros_3 = range(51,70,2)
print(Numeros_3)
print("El tipo de datos de Numeos_textos es:",type(Numeros_texto))


print("-------Otra cosa----------")

print("El tipo de datos de Numeros_3 es:",type(Numeros_3))


print("El tipo de datos de Numeros_3 es:",type(Numeros_Series_3))
Numeros_Series_3 = pd.Series(Numeros_3, index=Numeros_texto)
Numeros_Series_3
# Out:
# range(51, 70, 2)
# El tipo de datos de Numeos_textos es: <class 'list'>
# -------Otra cosa----------
# El tipo de datos de Numeros_3 es: <class 'range'>
# El tipo de datos de Numeros_3 es: <class 'pandas.core.series.Series'>
# primero    51
# segundo    53
# tercero    55
# cuarto     57
# quinto     59
# sexto      61
# septimo    63
# octavo     65
# noveno     67
# decimo     69
# dtype: int64

# %%
Numero_Series_2_porcion = Numero_Series_2[4:7]
Numero_Series_3_porcion = Numeros_Series_3[5:8]

# %%
print(Numero_Series_2_porcion + Numero_Series_3_porcion)
# Out:
# octavo       NaN
# quinto       NaN
# septimo    125.0
# sexto      121.0
# dtype: float64

# %%
Numero_Series_2_porcion.add(Numero_Series_3_porcion,fill_value=0)
# Out:
# octavo      65.0
# quinto      58.0
# septimo    125.0
# sexto      121.0
# dtype: float64

# %%
# Vamos a crear una estructura de serie
import pandas as pd

serie_otra= pd.Series(data=[1,2,3,4],index=['David','Juan',1,2],name='SerieX')
serie_otra
# Out:
# David    1
# Juan     2
# 1        3
# 2        4
# Name: SerieX, dtype: int64

# %%
# Algunas propiedades de la serie
print('Indice de la serie:',serie.index)
print('Valores de la serie:',serie.values)
print('Longitud de serie:',serie.count())
# Verificar nulos en la serie
serie.isna()
# Out:
# Indice de la serie: Index(['David', 'Juan', 1, 2], dtype='object')
# Valores de la serie: [1 2 3 4]
# Longitud de serie: 4
# David    False
# Juan     False
# 1        False
# 2        False
# Name: SerieX, dtype: bool

# %% [markdown]
# **serie.loc** se utiliza para localizar una fila a partir de su indide literal

# %%
# Filtrar un indice
serie.loc['Juan']
# Out:
# 2

# %% [markdown]
# **serie.iloc** se utiliza para seleccionar datos según su posición numérica (0, 1, 2, ...) en lugar de sus etiquetas o nombres de índice.

# %%
# Filtrar pero de otra forma
serie.iloc[0:42]

#Se utiliza para seleccionar datos según su posición numérica (0, 1, 2, ...) en lugar de sus etiquetas o nombres de índice.
# Out:
# David    1
# Juan     2
# 1        3
# 2        4
# Name: SerieX, dtype: int64

# %%
# Filtrar varios indices
serie.loc[['David',1]]
# Out:
# David    1
# 1        3
# Name: SerieX, dtype: int64

# %%
serie_otra
print("----------------")
print(serie_otra)
# Out:
# ----------------
# David    1
# Juan     2
# 1        3
# 2        4
# Name: SerieX, dtype: int64

# %%
import numpy as np

serie_2 = pd.Series(data=[1,2,5,6,np.nan,20,np.nan])
serie_2
# Out:
# 0     1.0
# 1     2.0
# 2     5.0
# 3     6.0
# 4     NaN
# 5    20.0
# 6     NaN
# dtype: float64

# %%
# Suma de nulos
serie_2.isnull().sum()
# Out:
# 2

# %%
# Conteo de valores no tiene en cuenta los NaN
serie_2.value_counts()
# Out:
# 1.0     1
# 2.0     1
# 5.0     1
# 6.0     1
# 20.0    1
# dtype: int64

# %%
# Creemos un dataframe
valores= [1000, 3500, 3000, 4000, 3000 , 2450]
nombres= ['David','Juan','Pedro','Lucas','Andrea','Felipe']
genero=['M','M','M','M','F','M']
df= pd.DataFrame(data={'salarios':valores, 'genero':genero},index=nombres)
df
# Out:
#         salarios genero
# David       1000      M
# Juan        3500      M
# Pedro       3000      M
# Lucas       4000      M
# Andrea      3000      F
# Felipe      2450      M

# %%
# filtremos por genero
df_m = df[df['genero']=='M']
print(df_m.head())
print('------')
df_f=df[df['genero']=='F']
print(df_f.head())
# Out:
#         salarios genero
# David       1000      M
# Juan        3500      M
# Pedro       3000      M
# Lucas       4000      M
# Felipe      2450      M
# ------
#         salarios genero
# Andrea      3000      F

# %%
# Otra forma
condicion_h = df['genero']=='M'
condicion_m = df['genero']=='F'
print(df[condicion_h])
print('-------------')
print(df[condicion_m])
# Out:
#         salarios genero
# David       1000      M
# Juan        3500      M
# Pedro       3000      M
# Lucas       4000      M
# Felipe      2450      M
# -------------
#         salarios genero
# Andrea      3000      F

# %%
# Algunas cosas adicionales
df.loc['David'][['salarios','genero']]
# Out:
# salarios    1000
# genero         M
# Name: David, dtype: object

# %%
df.loc[['David','Juan']][['salarios','genero']]
# Out:
#        salarios genero
# David      1000      M
# Juan       3500      M

# %% [markdown]
# # Lectura de csv / txt

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')

# %%
#%cd '/content/gdrive/MyDrive'
df= pd.read_csv('/content/winequality-red.csv',sep=',')
print(df[['density','pH','sulphates','alcohol','quality']].head())
# Out:
#    density    pH  sulphates  alcohol  quality
# 0   0.9978  3.51       0.56      9.4        5
# 1   0.9968  3.20       0.68      9.8        5
# 2   0.9970  3.26       0.65      9.8        5
# 3   0.9980  3.16       0.58      9.8        6
# 4   0.9978  3.51       0.56      9.4        5

# %%
#%cd '/content/gdrive/MyDrive'
df= pd.read_csv('/content/pokemon_data.txt',delimiter='\t')
print(df[['Name','Type 1','HP','Attack','Defense']].head())
# Out:
#                     Name Type 1  HP  Attack  Defense
# 0              Bulbasaur  Grass  45      49       49
# 1                Ivysaur  Grass  60      62       63
# 2               Venusaur  Grass  80      82       83
# 3  VenusaurMega Venusaur  Grass  80     100      123
# 4             Charmander   Fire  39      52       43

# %% [markdown]
# # Lectura de xlsx

# %%
#%cd '/content/gdrive/MyDrive'
df= pd.read_excel('/content/defaultoutput.xlsx')
print(df[['index','ID','Year_Birth','Education','Income']].head())
# Out:
#    index    ID  Year_Birth   Education   Income
# 0      0  5524        1957  Graduation  58138.0
# 1      1  2174        1954  Graduation  46344.0
# 2      2  4141        1965  Graduation  71613.0
# 3      3  6182        1984  Graduation  26646.0
# 4      4  5324        1981         PhD  58293.0

# %% [markdown]
# # Lectura desde Github /Apis

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/JJTorresDS/stocks-ds-edu/main/stocks.csv'
df = pd.read_csv(url, index_col=0)
print(df[['AMZN','MCD','SBUX','GOOG','MSFT']].head().round(1))
# Out:
#                  AMZN    MCD  SBUX   GOOG  MSFT
# formatted_date
# 2016-01-01      587.0  106.3  54.4  743.0  49.9
# 2016-02-01      552.5  100.7  52.1  697.8  46.0
# 2016-03-01      593.6  108.8  53.6  745.0  50.3
# 2016-04-01      659.6  109.5  50.5  693.0  45.5
# 2016-05-01      722.8  105.6  49.3  735.7  48.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   formatted_date  71 non-null     object
#  1   MCD             71 non-null     float64
#  2   SBUX            71 non-null     float64
#  3   GOOG            71 non-null     float64
#  4   AMZN            71 non-null     float64
#  5   MSFT            71 non-null     float64
#  6   JPM             71 non-null     float64
#  7   BAC             71 non-null     float64
#  8   C               71 non-null     float64
#  9   MAR             71 non-null     float64
#  10  HLT             71 non-null     float64
#  11  RCL             71 non-null     float64
#  12  V               71 non-null     float64
#  13  MA              71 non-null     float64
#  14  PYPL            71 non-null     float64
# dtypes: float64(14), object(1)
# memory usage: 8.4+ KB

# %%
# !wget -O cars_clus.csv https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/cars_clus.csv
# Out:
# --2024-11-22 21:16:33--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/cars_clus.csv
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17774 (17K) [text/csv]
# Saving to: ‘cars_clus.csv’
#
# cars_clus.csv       100%[===================>]  17.36K  --.-KB/s    in 0s
#
# 2024-11-22 21:16:34 (193 MB/s) - ‘cars_clus.csv’ saved [17774/17774]

# %%
filename = 'cars_clus.csv'
#Lectura
pdf = pd.read_csv(filename)
print ("Shape: ", pdf.shape)

print("1--------------------")

filename

print("2--------------------")

print(pdf[['manufact','model','sales','resale']].head(5))
# Out:
# Shape:  (159, 16)
# 1--------------------
# 2--------------------
#   manufact    model   sales  resale
# 0    Acura  Integra  16.919  16.360
# 1    Acura       TL  39.384  19.875
# 2    Acura       CL  14.114  18.225
# 3    Acura       RL   8.588  29.725
# 4     Audi       A4  20.397  22.255

# %% [markdown]
# # Lectura de informacion
#
# Los datos se encuentran en la siguiente link:
# [Data Acciones](https://raw.githubusercontent.com/JJTorresDS/stocks-ds-edu/main/stocks.csv)

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/JJTorresDS/stocks-ds-edu/main/stocks.csv'
df = pd.read_csv(url, index_col=0)
print(df.head(5))
# Out:
#                        MCD       SBUX        GOOG        AMZN       MSFT  \
# formatted_date
# 2016-01-01      106.332146  54.353962  742.950012  587.000000  49.853489
# 2016-02-01      100.671043  52.064243  697.770020  552.520020  46.043667
# 2016-03-01      108.782211  53.571442  744.950012  593.640015  50.339031
# 2016-04-01      109.483307  50.457645  693.010010  659.590027  45.453705
# 2016-05-01      105.648926  49.255203  735.719971  722.789978  48.306515
#
#                       JPM        BAC          C        MAR        HLT  \
# formatted_date
# 2016-01-01      50.424938  12.573010  36.897804  57.754189  35.192841
# 2016-02-01      48.033066  11.132540  33.707108  64.228912  41.061607
# 2016-03-01      50.524323  12.021718  36.223217  67.336624  44.499886
# 2016-04-01      53.919910  12.995729  40.153545  66.305466  43.716049
# 2016-05-01      56.098225  13.201019  40.447887  62.474155  41.198154
#
#                       RCL          V         MA       PYPL
# formatted_date
# 2016-01-01      74.235298  71.574371  85.822624  36.139999
# 2016-02-01      67.360649  69.556580  83.956566  38.139999
# 2016-03-01      74.790009  73.631477  91.278160  38.599998
# 2016-04-01      70.465584  74.363144  93.683258  39.180000
# 2016-05-01      70.456474  75.999847  92.817329  37.790001

# %%
print(df.columns)
print("--------------------")

df.head()
# Out:
# Index(['MCD', 'SBUX', 'GOOG', 'AMZN', 'MSFT', 'JPM', 'BAC', 'C', 'MAR', 'HLT',
#        'RCL', 'V', 'MA', 'PYPL'],
#       dtype='object')
# --------------------
#                        MCD       SBUX        GOOG        AMZN       MSFT  \
# formatted_date
# 2016-01-01      106.332146  54.353962  742.950012  587.000000  49.853489
# 2016-02-01      100.671043  52.064243  697.770020  552.520020  46.043667
# 2016-03-01      108.782211  53.571442  744.950012  593.640015  50.339031
# 2016-04-01      109.483307  50.457645  693.010010  659.590027  45.453705
# 2016-05-01      105.648926  49.255203  735.719971  722.789978  48.306515
#
#                       JPM        BAC          C        MAR        HLT  \
# formatted_date
# 2016-01-01      50.424938  12.573010  36.897804  57.754189  35.192841
# 2016-02-01      48.033066  11.132540  33.707108  64.228912  41.061607
# 2016-03-01      50.524323  12.021718  36.223217  67.336624  44.499886
# 2016-04-01      53.919910  12.995729  40.153545  66.305466  43.716049
# 2016-05-01      56.098225  13.201019  40.447887  62.474155  41.198154
#
#                       RCL          V         MA       PYPL
# formatted_date
# 2016-01-01      74.235298  71.574371  85.822624  36.139999
# 2016-02-01      67.360649  69.556580  83.956566  38.139999
# 2016-03-01      74.790009  73.631477  91.278160  38.599998
# 2016-04-01      70.465584  74.363144  93.683258  39.180000
# 2016-05-01      70.456474  75.999847  92.817329  37.790001

# %% [markdown]
# Miremos el tamaño de nuestro datraframe

# %%
df.shape
# Out:
# (71, 14)

# %% [markdown]
# 71 filas x 14 columnas

# %% [markdown]
# Las columnas son los precios de acciones de:
#
# 1. MCD: Macdonals
# 2. SBUX: Starbucks
# 3. GOOG: Google
# 4. AMZN: Amazon
# 5. MSFT: Microsoft
# 6. JPM: JPMorgan Chase & Co.
# 7. BAC: Bank of America Corp
# 8. C: Citigroup
# 9. MAR: Pharma MAr
# 10. HLT: Hoteles Hilton
# 11. RCL: Royal Caribbean Cruises
# 12. V: Visa Inc.
# 13. MA: Mastercard
# 14. PYPL: Paypal

# %% [markdown]
# # Analizando el comportamiento de una serie de tiempo

# %%
df['MA'].plot(kind='line',figsize=(10,6),xlabel='Fecha', ylabel='Precio Accion', title='Precio Accion vs Fecha')

#('line', 'bar', 'barh', 'kde', 'density', 'area', 'hist', 'box', 'pie', 'scatter', 'hexbin')
# Out:
# <Axes: title={'center': 'Precio Accion vs Fecha'}, xlabel='Fecha', ylabel='Precio Accion'>

# %% [markdown]
# Se observa un comportamiento creciente entre el 01/01/21 hasta el 11/01/2021

# %% [markdown]
# # Grafiquemos todas las series de tiempo

# %%
df.plot(kind='line',figsize=(15,6),xlabel='Fecha', ylabel='Precio Accion', title='Precio Accion vs Fecha').legend(loc='best')

# %% [markdown]
# **En cual accion invertirian y porque?**

# %% [markdown]
# Al parecer hay una gran diferencia en el comportamiento de las acciones **GOOG (Google) y AMZN (Amazon)** respecto a las demás, por otro lado podemos analizar el porcentaje de cambio cada día para entender como estan sucediendo los cambios diarios de manera porcentual

# %%
df_cambios=df.pct_change()*100
df_cambios
# Out:
#                      MCD      SBUX       GOOG       AMZN       MSFT       JPM  \
# formatted_date
# 2016-01-01           NaN       NaN        NaN        NaN        NaN       NaN
# 2016-02-01     -5.323980 -4.212607  -6.081162  -5.873932  -7.642037 -4.743432
# 2016-03-01      8.057101  2.894882   6.761539   7.442263   9.328893  5.186545
# 2016-04-01      0.644495 -5.812418  -6.972280  11.109428  -9.704848  6.720700
# 2016-05-01     -3.502252 -2.383072   6.162965   9.581702   6.276298  4.039907
# ...                  ...       ...        ...        ...        ...       ...
# 2021-07-01      5.073810  8.603882   7.904013  -3.272226   5.171653 -2.417375
# 2021-08-01     -2.163073 -3.244671   7.573531   4.303413   5.956268  5.990058
# 2021-09-01      2.093757 -5.746744  -8.384662  -5.351807  -6.433113  2.338235
# 2021-10-01      1.841486 -3.843711  11.259473   2.660238  17.629108  3.787643
# 2021-11-01     -0.386887  3.365701  -3.924242   3.992378  -0.310593 -5.946732
#
#                       BAC          C        MAR        HLT        RCL  \
# formatted_date
# 2016-01-01            NaN        NaN        NaN        NaN        NaN
# 2016-02-01     -11.456848  -8.647389  11.210830  16.676025  -9.260620
# 2016-03-01       7.987201   7.464626   4.838494   8.373462  11.029228
# 2016-04-01       8.102098  10.850302  -1.531349  -1.761435  -5.782089
# 2016-05-01       1.579672   0.733041  -5.778272  -5.759658  -0.012928
# ...                   ...        ...        ...        ...        ...
# 2021-07-01      -6.569298  -4.424032   6.929381   8.978606  -9.861628
# 2021-08-01       8.837328   7.138355  -7.425672  -5.013310   7.623261
# 2021-09-01       1.676649  -2.405785   9.582653   5.806503   7.518425
# 2021-10-01      13.132745  -1.453400   8.055918   8.962226  -5.081503
# 2021-11-01      -6.927583  -7.227223  -7.786531  -6.168802 -17.304276
#
#                        V         MA       PYPL
# formatted_date
# 2016-01-01           NaN        NaN        NaN
# 2016-02-01     -2.819154  -2.174320   5.534034
# 2016-03-01      5.858393   8.720693   1.206080
# 2016-04-01      0.993687   2.634911   1.502595
# 2016-05-01      2.200961  -0.924315  -3.547727
# ...                  ...        ...        ...
# 2021-07-01      5.375928   5.710923  -5.472078
# 2021-08-01     -7.017328 -10.183470   4.765363
# 2021-09-01     -2.639177   0.418791  -9.855890
# 2021-10-01     -4.929288  -3.497477 -10.614502
# 2021-11-01     -8.499787  -6.021122 -20.508189
#
# [71 rows x 14 columns]

# %%
df_cambios.plot(kind='line',figsize=(15,6),xlabel='Fecha', ylabel='Porcentaje de cambio', title='Precio Accion vs Fecha').legend(loc='best')

# %% [markdown]
# **Siguen pensando lo mismo respecto a la pregunta anterior**
# Teniendo en cuenta esta información cual sería a la acción en la cual invertirian?

# %% [markdown]
# La respuesta en que accion invertir no solo pasa por el valor de la acción en si sino mas bien por factores asociados a la volatididad que pueda tener la acción.
#
# Cuando se prefiere aversion al riesgo (evitar incertidumbre en inversiones) se requieren acciones que tengan poca volatilidad. 🧱 🈶 ☁ 🪗 ❎
#
# Por el contrario cuando se asumen riesgos las inversiones podrían enfocarse en aquellas acciones con mayor volatilidad ⏰ ⚗ ⛹ ♟

# %% [markdown]
# # Grafico interactivo
#
# Para generar un grafico dinamico podemos usar plotly con el fin de poder establecer el valor en cada momento del tiempo para cada accion
#
# Ademas debemos hacer uso de la funcion ```melt``` que explicaremos posteriormente mas adelante pero consiste en formato long del dataframe para facilitar el grafico en plotly

# %%
df_n=df.copy()
df_n['Fecha']=df.index
df_n= df_n.reset_index(drop=True)
df_n.round(1)
# Out:
#       MCD   SBUX    GOOG    AMZN   MSFT    JPM   BAC     C    MAR    HLT  \
# 0   106.3   54.4   743.0   587.0   49.9   50.4  12.6  36.9   57.8   35.2
# 1   100.7   52.1   697.8   552.5   46.0   48.0  11.1  33.7   64.2   41.1
# 2   108.8   53.6   745.0   593.6   50.3   50.5  12.0  36.2   67.3   44.5
# 3   109.5   50.5   693.0   659.6   45.5   53.9  13.0  40.2   66.3   43.7
# 4   105.6   49.3   735.7   722.8   48.3   56.1  13.2  40.4   62.5   41.2
# ..    ...    ...     ...     ...    ...    ...   ...   ...    ...    ...
# 66  240.1  120.4  2704.4  3327.6  283.8  150.0  38.0  66.6  146.0  131.4
# 67  234.9  116.5  2909.2  3470.8  300.8  159.0  41.3  71.4  135.1  124.9
# 68  239.8  109.8  2665.3  3285.0  281.4  162.7  42.0  69.7  148.1  132.1
# 69  244.2  105.6  2965.4  3372.4  331.0  168.9  47.6  68.7  160.0  143.9
# 70  243.3  109.2  2849.0  3507.1  330.0  158.8  44.3  63.7  147.6  135.1
#
#      RCL      V     MA   PYPL       Fecha
# 0   74.2   71.6   85.8   36.1  2016-01-01
# 1   67.4   69.6   84.0   38.1  2016-02-01
# 2   74.8   73.6   91.3   38.6  2016-03-01
# 3   70.5   74.4   93.7   39.2  2016-04-01
# 4   70.5   76.0   92.8   37.8  2016-05-01
# ..   ...    ...    ...    ...         ...
# 66  76.9  245.6  385.0  275.5  2021-07-01
# 67  82.7  228.4  345.8  288.7  2021-08-01
# 68  88.9  222.4  347.2  260.2  2021-09-01
# 69  84.4  211.4  335.1  232.6  2021-10-01
# 70  69.8  193.4  314.9  184.9  2021-11-01
#
# [71 rows x 15 columns]

# %%
df_long=pd.melt(df_n , value_vars=df.columns,id_vars='Fecha')
df_long
# Out:
#           Fecha variable       value
# 0    2016-01-01      MCD  106.332146
# 1    2016-02-01      MCD  100.671043
# 2    2016-03-01      MCD  108.782211
# 3    2016-04-01      MCD  109.483307
# 4    2016-05-01      MCD  105.648926
# ..          ...      ...         ...
# 989  2021-07-01     PYPL  275.529999
# 990  2021-08-01     PYPL  288.660004
# 991  2021-09-01     PYPL  260.209991
# 992  2021-10-01     PYPL  232.589996
# 993  2021-11-01     PYPL  184.889999
#
# [994 rows x 3 columns]

# %%
import plotly.express as px


fig=px.line(data_frame=df_long,x='Fecha',y='value',line_group='variable',color='variable',title='Comportamiento de precio de acciones',\
             labels={
                     "Fecha": "Fecha_dias",
                     "value": "Precio (USD)"
                 })
fig.update_layout(paper_bgcolor="#FFFFFF",plot_bgcolor='#FFFFFF',)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e170c693-bd4c-4a27-9286-256f12a08b2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e170c693-bd4c-4a27-9286-256f12a08b2d")) {                    Plotly.newPlot(                        "e170c693-bd4c-4a27-9286-256f12a08b2d",                        [{"hovertemplate":"variable=MCD\u003cbr\u003eFecha_dias=%{x}\u003cbr\u003ePrecio (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MCD","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"MCD","orientation":"v","showlegend":true,"x":["2016-01-01","2016-02-01","2016-03-01","2016-04-01","2016-05-01","2016-06-01","2016-07-01","2016-08-01","2016-09-01","2016-10-01","2016-11-01","2016-12-01","2017-01-01","2017-02-01","2017-03-01","2017-04-01","2017-05-01","2017-06-01","2017-07-01","2017-08-01","2017-09-01","2017-10-01","2017-11-01","2017-12-01","2018-01-01","2018-02-01","2018-03-01","2018-04-01","2018-05-01","2018-06-01","2018-07-01","2018-08-01","2018-09-01","2018-10-01","2018-11-01","2018-12-01","2019-01-01","2019-02-01","2019-03-01","2019-04-01","2019-05-01","2019-06-01","2019-07-01","2019-08-01","2019-09-01","2019-10-01","2019-11-01","2019-12-01","2020-01-01","2020-02-01","2020-03-01","2020-04-01","2020-05-01","2020-06-01","2020-07-01","2020-08-01","2020-09-01","2020-10-01","2020-11-01","2020-12-01","2021-01-01","2021-02-01","2021-03-01","2021-04-01","2021-05-01","2021-06-01","2021-07-01","2021-08-01","2021-09-01","2021-10-01","2021-11-01"],"xaxis":"x","y":[106.33214569091795,100.6710433959961,108.78221130371094,109.48330688476562,105.64892578125,104.1601791381836,102.5803680419922,100.84526824951172,101.36538696289062,98.9138412475586,104.8010482788086,107.7855453491211,108.53822326660156,113.03667449951172,115.6170654296875,124.82291412353516,134.5996551513672,136.62457275390625,139.25833129882812,143.59390258789062,141.47509765625,150.7123260498047,155.28128051757812,156.34323120117188,155.4530792236328,143.28131103515625,142.9446258544922,153.05442810058594,146.2627716064453,143.22801208496094,144.9197235107422,149.23403930664062,154.849365234375,163.7446746826172,174.49127197265625,165.37850952148438,166.5054168701172,171.21800231933594,177.98794555664062,185.1768341064453,185.8329162597656,195.77374267578125,198.65858459472656,205.49362182617188,203.49050903320312,186.42161560058597,184.31759643554688,188.4842987060547,204.08880615234372,185.2031707763672,158.70103454589844,180.01791381835938,178.82778930664062,178.23263549804688,187.71095275878903,206.30039978027344,213.30923461914065,207.00198364257807,211.31695556640625,209.77696228027344,203.1878204345703,201.52587890625,220.47120666503903,232.21575927734372,230.0616149902344,228.4639587402344,240.0557861328125,234.8632049560547,239.7806701660156,244.1961975097656,243.25143432617188],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=SBUX\u003cbr\u003eFecha_dias=%{x}\u003cbr\u003ePrecio (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SBUX","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"SBUX","orientation":"v","showlegend":true,"x":["2016-01-01","2016-02-01","2016-03-01","2016-04-01","2016-05-01","2016-06-01","2016-07-01","2016-08-01","2016-09-01","2016-10-01","2016-11-01","2016-12-01","2017-01-01","2017-02-01","2017-03-01","2017-04-01","2017-05-01","2017-06-01","2017-07-01","2017-08-01","2017-09-01","2017-10-01","2017-11-01","2017-12-01","2018-01-01","2018-02-01","2018-03-01","2018-04-01","2018-05-01","2018-06-01","2018-07-01","2018-08-01","2018-09-01","2018-10-01","2018-11-01","2018-12-01","2019-01-01","2019-02-01","2019-03-01","2019-04-01","2019-05-01","2019-06-01","2019-07-01","2019-0 ...

# %% [markdown]
# # Excluyendo Amazon y GOOGLE

# %%
df_n=df.copy()
df_n['Fecha']=df.index
df_n= df_n.reset_index(drop=True)
df_n= df_n.drop(columns=['GOOG','AMZN'])
df_n
# Out:
#            MCD        SBUX        MSFT         JPM        BAC          C  \
# 0   106.332146   54.353962   49.853489   50.424938  12.573010  36.897804
# 1   100.671043   52.064243   46.043667   48.033066  11.132540  33.707108
# 2   108.782211   53.571442   50.339031   50.524323  12.021718  36.223217
# 3   109.483307   50.457645   45.453705   53.919910  12.995729  40.153545
# 4   105.648926   49.255203   48.306515   56.098225  13.201019  40.447887
# ..         ...         ...         ...         ...        ...        ...
# 66  240.055786  120.441193  283.846313  150.006454  37.981613  66.635887
# 67  234.863205  116.533272  300.752960  158.991928  41.338173  71.392593
# 68  239.780670  109.836403  281.405182  162.709534  42.031269  69.675041
# 69  244.196198  105.614609  331.014404  168.872391  47.551128  68.662384
# 70  243.251434  109.169281  329.986298  158.830002  44.256985  63.700001
#
#            MAR         HLT        RCL           V          MA        PYPL  \
# 0    57.754189   35.192841  74.235298   71.574371   85.822624   36.139999
# 1    64.228912   41.061607  67.360649   69.556580   83.956566   38.139999
# 2    67.336624   44.499886  74.790009   73.631477   91.278160   38.599998
# 3    66.305466   43.716049  70.465584   74.363144   93.683258   39.180000
# 4    62.474155   41.198154  70.456474   75.999847   92.817329   37.790001
# ..         ...         ...        ...         ...         ...         ...
# 66  145.979996  131.449997  76.870003  245.622177  384.999420  275.529999
# 67  135.139999  124.860001  82.730003  228.386063  345.793121  288.660004
# 68  148.089996  132.110001  88.949997  222.358551  347.241272  260.209991
# 69  160.020004  143.949997  84.430000  211.397858  335.096588  232.589996
# 70  147.559998  135.070007  69.820000  193.429489  314.920013  184.889999
#
#          Fecha
# 0   2016-01-01
# 1   2016-02-01
# 2   2016-03-01
# 3   2016-04-01
# 4   2016-05-01
# ..         ...
# 66  2021-07-01
# 67  2021-08-01
# 68  2021-09-01
# 69  2021-10-01
# 70  2021-11-01
#
# [71 rows x 13 columns]

# %%
columnas=list(df.columns)
unwanted_num = {'AMZN', 'GOOG'}

col_final = [x for x in columnas if x not in unwanted_num]
col_final
# Out:
# ['MCD',
#  'SBUX',
#  'MSFT',
#  'JPM',
#  'BAC',
#  'C',
#  'MAR',
#  'HLT',
#  'RCL',
#  'V',
#  'MA',
#  'PYPL']

# %%
df_long = pd.melt(df_n , value_vars=col_final,id_vars='Fecha')
df_long
# Out:
#           Fecha variable       value
# 0    2016-01-01      MCD  106.332146
# 1    2016-02-01      MCD  100.671043
# 2    2016-03-01      MCD  108.782211
# 3    2016-04-01      MCD  109.483307
# 4    2016-05-01      MCD  105.648926
# ..          ...      ...         ...
# 847  2021-07-01     PYPL  275.529999
# 848  2021-08-01     PYPL  288.660004
# 849  2021-09-01     PYPL  260.209991
# 850  2021-10-01     PYPL  232.589996
# 851  2021-11-01     PYPL  184.889999
#
# [852 rows x 3 columns]

# %%
import plotly.express as px


fig=px.line(data_frame=df_long,x='Fecha',y='value',line_group='variable',color='variable',title='Comportamiento de precio de acciones',\
             labels={
                     "Fecha": "Fecha_dias",
                     "value": "Precio (USD)"
                 })
fig.update_layout(paper_bgcolor="#FFFFFF",plot_bgcolor='#FFFFFF',)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="052f6313-bb82-4439-9263-d8cd5f950381" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("052f6313-bb82-4439-9263-d8cd5f950381")) {                    Plotly.newPlot(                        "052f6313-bb82-4439-9263-d8cd5f950381",                        [{"hovertemplate":"variable=MCD\u003cbr\u003eFecha_dias=%{x}\u003cbr\u003ePrecio (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MCD","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"MCD","orientation":"v","showlegend":true,"x":["2016-01-01","2016-02-01","2016-03-01","2016-04-01","2016-05-01","2016-06-01","2016-07-01","2016-08-01","2016-09-01","2016-10-01","2016-11-01","2016-12-01","2017-01-01","2017-02-01","2017-03-01","2017-04-01","2017-05-01","2017-06-01","2017-07-01","2017-08-01","2017-09-01","2017-10-01","2017-11-01","2017-12-01","2018-01-01","2018-02-01","2018-03-01","2018-04-01","2018-05-01","2018-06-01","2018-07-01","2018-08-01","2018-09-01","2018-10-01","2018-11-01","2018-12-01","2019-01-01","2019-02-01","2019-03-01","2019-04-01","2019-05-01","2019-06-01","2019-07-01","2019-08-01","2019-09-01","2019-10-01","2019-11-01","2019-12-01","2020-01-01","2020-02-01","2020-03-01","2020-04-01","2020-05-01","2020-06-01","2020-07-01","2020-08-01","2020-09-01","2020-10-01","2020-11-01","2020-12-01","2021-01-01","2021-02-01","2021-03-01","2021-04-01","2021-05-01","2021-06-01","2021-07-01","2021-08-01","2021-09-01","2021-10-01","2021-11-01"],"xaxis":"x","y":[106.33214569091795,100.6710433959961,108.78221130371094,109.48330688476562,105.64892578125,104.1601791381836,102.5803680419922,100.84526824951172,101.36538696289062,98.9138412475586,104.8010482788086,107.7855453491211,108.53822326660156,113.03667449951172,115.6170654296875,124.82291412353516,134.5996551513672,136.62457275390625,139.25833129882812,143.59390258789062,141.47509765625,150.7123260498047,155.28128051757812,156.34323120117188,155.4530792236328,143.28131103515625,142.9446258544922,153.05442810058594,146.2627716064453,143.22801208496094,144.9197235107422,149.23403930664062,154.849365234375,163.7446746826172,174.49127197265625,165.37850952148438,166.5054168701172,171.21800231933594,177.98794555664062,185.1768341064453,185.8329162597656,195.77374267578125,198.65858459472656,205.49362182617188,203.49050903320312,186.42161560058597,184.31759643554688,188.4842987060547,204.08880615234372,185.2031707763672,158.70103454589844,180.01791381835938,178.82778930664062,178.23263549804688,187.71095275878903,206.30039978027344,213.30923461914065,207.00198364257807,211.31695556640625,209.77696228027344,203.1878204345703,201.52587890625,220.47120666503903,232.21575927734372,230.0616149902344,228.4639587402344,240.0557861328125,234.8632049560547,239.7806701660156,244.1961975097656,243.25143432617188],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=SBUX\u003cbr\u003eFecha_dias=%{x}\u003cbr\u003ePrecio (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SBUX","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"SBUX","orientation":"v","showlegend":true,"x":["2016-01-01","2016-02-01","2016-03-01","2016-04-01","2016-05-01","2016-06-01","2016-07-01","2016-08-01","2016-09-01","2016-10-01","2016-11-01","2016-12-01","2017-01-01","2017-02-01","2017-03-01","2017-04-01","2017-05-01","2017-06-01","2017-07-01","2017-08-01","2017-09-01","2017-10-01","2017-11-01","2017-12-01","2018-01-01","2018-02-01","2018-03-01","2018-04-01","2018-05-01","2018-06-01","2018-07-01","2018-08-01","2018-09-01","2018-10-01","2018-11-01","2018-12-01","2019-01-01","2019-02-01","2019-03-01","2019-04-01","2019-05-01","2019-06-01","2019-07-01","2019-0 ...

# %% [markdown]
# Ahora se pueden ver mucho mejor las fluctuaciones de cada compañia que antes no era tan claro
